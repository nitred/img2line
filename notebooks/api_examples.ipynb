# %%
# %matplotlib notebook
import warnings
warnings.filterwarnings('ignore')
from img2line import fit_line_to_image, fit_gpr_to_image

# %% [markdown]
# ### Polynomial Regression (degree 5) on a Simple Line

# %%
x, y, model = fit_line_to_image("./line.png", degree=5, plot=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Polynomial Regression (degree 12) on a Simple Line (Unreliable)

# %%
x, y, model = fit_line_to_image("./line.png", degree=12, plot=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Gaussian Process Regression on Complex Line

# %%
x, y, model = fit_gpr_to_image("./complex_line.png", plot=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
